# %% [markdown]
# # torch.Tensor
#
# Los tensores son estructuras de datos que contienen elementos de un único tipo de datos.

# %%
import numpy as np
import matplotlib as mpl
import time
import torch

# %% [markdown]
# # Inicialización de Tensores

# %%
print("+ Inicialización de tensores:")
# Inicialización de un tensor con una lista
t = torch.tensor([[1., -1.], [1., -1.]])
print(f"- Con lista: {t}, dtype: {t.dtype}")

# Inicialización de un tensor con numpy
t = torch.tensor(np.array([[1, 2, 3], [4, 5, 6]]))
print(f"- Con numpy: {t}, dtype: {t.dtype}")
# Out:
# + Inicialización de tensores:
# - Con lista: tensor([[ 1., -1.],
#         [ 1., -1.]]), dtype: torch.float32
# - Con numpy: tensor([[1, 2, 3],
#         [4, 5, 6]]), dtype: torch.int64

# %% [markdown]
# # Copia y referencia de Tensores

# %%
t = torch.randint(0, 100, [10, 15], dtype=torch.uint32) # crea un nuevo tensor
t0 = torch.tensor(t) # copia el tensor
t1 = torch.as_tensor(t) # hace referencia al tensor
print(t)
t.data_ptr(), t0.data_ptr(), t.data_ptr() == t0.data_ptr(), t1.data_ptr(), t.data_ptr() == t1.data_ptr()
# Out:
# tensor([[35, 84, 16, 23, 99, 25, 42, 56, 31, 18, 57, 61, 91, 92, 25],
#         [19,  2, 34, 13, 24, 82, 55,  3, 91, 29, 67, 66, 93, 67, 62],
#         [31, 40, 20,  1, 88, 99, 56, 15, 41, 70,  1, 95, 28, 55, 60],
#         [95, 30, 71,  7, 22, 69, 45, 64, 10, 16, 41,  5, 91, 47, 36],
#         [89, 95,  3,  2, 81, 67, 42, 83, 50, 69, 18, 85, 93, 96, 98],
#         [ 6,  6, 99, 91, 50,  6, 78, 81, 52, 19,  8, 49, 17, 85, 64],
#         [49,  8, 58, 93, 73, 47, 63,  0, 55, 52, 47, 54, 58,  2, 53],
#         [23, 47, 90, 95, 87, 39, 10, 36, 11, 47, 17, 68, 48, 61, 48],
#         [19, 60, 75, 98, 47, 87, 94, 44,  9, 81, 17, 31, 82, 58, 71],
#         [72, 53,  4, 75, 85, 67, 26, 85, 52, 49, 51, 91, 97, 52, 47]],
#        dtype=torch.uint32)
# C:\Users\derli\AppData\Local\Temp\ipykernel_2060\498220540.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t0 = torch.tensor(t) # copia el tensor
# (4931214311424, 4931214312192, False, 4931214311424, True)

# %%
data = [[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]]
t = torch.tensor(data)
t, t.dtype, t.dim(), t.dim_order()
# Out:
# (tensor([[1, 2, 3],
#          [4, 5, 6]]),
#  torch.int64,
#  2,
#  (0, 1))
